# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-9b/Machine-Learning-Data-preprocessing/blob/main/Task_1_Data_Preprocessing_for_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Find the missing data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum() / df.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df.drop("Cabin", axis = 1, inplace = True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.isnull().sum() / df.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Embarked       0.002245
# dtype: float64

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.isnull().sum() / df.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Embarked       0.000000
# dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.drop(["Name", "PassengerId" , "Ticket"] , inplace = True , axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
gender = pd.get_dummies(df.Sex)

# %%
df = df.join(gender)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  female  \
# 0         0       3    male  22.0      1      0   7.2500        S   False
# 1         1       1  female  38.0      1      0  71.2833        C    True
# 2         1       3  female  26.0      0      0   7.9250        S    True
# 3         1       1  female  35.0      1      0  53.1000        S    True
# 4         0       3    male  35.0      0      0   8.0500        S   False
#
#     male
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
pc = pd.get_dummies(df.Pclass , prefix = "pclass")

# %%
pc
# Out:
#      pclass_1  pclass_2  pclass_3
# 0       False     False      True
# 1        True     False     False
# 2       False     False      True
# 3        True     False     False
# 4       False     False      True
# ..        ...       ...       ...
# 886     False      True     False
# 887      True     False     False
# 888     False     False      True
# 889      True     False     False
# 890     False     False      True
#
# [891 rows x 3 columns]

# %%
df = df.join(pc)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  female  \
# 0         0       3    male  22.0      1      0   7.2500        S   False
# 1         1       1  female  38.0      1      0  71.2833        C    True
# 2         1       3  female  26.0      0      0   7.9250        S    True
# 3         1       1  female  35.0      1      0  53.1000        S    True
# 4         0       3    male  35.0      0      0   8.0500        S   False
#
#     male  pclass_1  pclass_2  pclass_3
# 0   True     False     False      True
# 1  False      True     False     False
# 2  False     False     False      True
# 3  False      True     False     False
# 4   True     False     False      True

# %%
em = pd.get_dummies(df.Embarked , prefix = "em")

# %%
em
# Out:
#       em_C   em_Q   em_S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %%
df = df.join(em)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  female  \
# 0         0       3    male  22.0      1      0   7.2500        S   False
# 1         1       1  female  38.0      1      0  71.2833        C    True
# 2         1       3  female  26.0      0      0   7.9250        S    True
# 3         1       1  female  35.0      1      0  53.1000        S    True
# 4         0       3    male  35.0      0      0   8.0500        S   False
#
#     male  pclass_1  pclass_2  pclass_3   em_C   em_Q   em_S
# 0   True     False     False      True  False  False   True
# 1  False      True     False     False   True  False  False
# 2  False     False     False      True  False  False   True
# 3  False      True     False     False  False  False   True
# 4   True     False     False      True  False  False   True

# %%
df.drop(["Sex" , "Pclass" , "Embarked"] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  female   male  pclass_1  pclass_2  \
# 0         0  22.0      1      0   7.2500   False   True     False     False
# 1         1  38.0      1      0  71.2833    True  False      True     False
# 2         1  26.0      0      0   7.9250    True  False     False     False
# 3         1  35.0      1      0  53.1000    True  False      True     False
# 4         0  35.0      0      0   8.0500   False   True     False     False
#
#    pclass_3   em_C   em_Q   em_S
# 0      True  False  False   True
# 1     False   True  False  False
# 2      True  False  False   True
# 3     False  False  False   True
# 4      True  False  False   True

# %%
sc_age = MinMaxScaler()

# %%
df["new_age"] = sc_age.fit_transform(df.Age.values.reshape(-1 , 1))

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  female   male  pclass_1  pclass_2  \
# 0         0  22.0      1      0   7.2500   False   True     False     False
# 1         1  38.0      1      0  71.2833    True  False      True     False
# 2         1  26.0      0      0   7.9250    True  False     False     False
# 3         1  35.0      1      0  53.1000    True  False      True     False
# 4         0  35.0      0      0   8.0500   False   True     False     False
#
#    pclass_3   em_C   em_Q   em_S   new_age
# 0      True  False  False   True  0.271174
# 1     False   True  False  False  0.472229
# 2      True  False  False   True  0.321438
# 3     False  False  False   True  0.434531
# 4      True  False  False   True  0.434531

# %%
sc_fare = MinMaxScaler()

# %%
df["new_fare"] = sc_fare.fit_transform(df.Fare.values.reshape(-1 , 1))

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  female   male  pclass_1  pclass_2  \
# 0         0  22.0      1      0   7.2500   False   True     False     False
# 1         1  38.0      1      0  71.2833    True  False      True     False
# 2         1  26.0      0      0   7.9250    True  False     False     False
# 3         1  35.0      1      0  53.1000    True  False      True     False
# 4         0  35.0      0      0   8.0500   False   True     False     False
#
#    pclass_3   em_C   em_Q   em_S   new_age  new_fare
# 0      True  False  False   True  0.271174  0.014151
# 1     False   True  False  False  0.472229  0.139136
# 2      True  False  False   True  0.321438  0.015469
# 3     False  False  False   True  0.434531  0.103644
# 4      True  False  False   True  0.434531  0.015713

# %%
df.drop(["Fare" , "Age"] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Survived  SibSp  Parch  female   male  pclass_1  pclass_2  pclass_3   em_C  \
# 0         0      1      0   False   True     False     False      True  False
# 1         1      1      0    True  False      True     False     False   True
# 2         1      0      0    True  False     False     False      True  False
# 3         1      1      0    True  False      True     False     False  False
# 4         0      0      0   False   True     False     False      True  False
#
#     em_Q   em_S   new_age  new_fare
# 0  False   True  0.271174  0.014151
# 1  False  False  0.472229  0.139136
# 2  False   True  0.321438  0.015469
# 3  False   True  0.434531  0.103644
# 4  False   True  0.434531  0.015713
